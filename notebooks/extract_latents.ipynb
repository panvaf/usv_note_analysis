# %% [markdown]
# # Extract latents to create time series of latent USV representations

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt

# %%
from ava.data.data_container import DataContainer
from ava.plotting.grid_plot import indexed_grid_plot_DC
import audio_utils.io
from itertools import repeat
from joblib import Parallel, delayed
from ava.preprocessing.utils import get_spec
from ava.models.vae import X_SHAPE, VAE
from ava.preprocessing.preprocess import process_sylls
import torch
# Out:
# /home/vafeidis/.conda/envs/behavior/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/vafeidis/.conda/envs/behavior/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/vafeidis/.conda/envs/behavior/lib/python3.11/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/vafeidis/.conda/envs/behavior/lib/python3.11/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
# %matplotlib inline

# %% [markdown]
# ## Ava project path

# %%
root = '/mnt/labNAS/usv_calls/usv_note_analysis/03_div_cage_group01_18_song_empty'
audio_dirs = [os.path.join(root, 'audio')]
seg_dirs = [os.path.join(root, 'segs')]
proj_dirs = [os.path.join(root, 'projections')]
spec_dirs = [os.path.join(root, 'specs')]
model_filename = os.path.join(root, 'checkpoint_200.tar')
plots_dir = root
dc = DataContainer(projection_dirs=proj_dirs, spec_dirs=spec_dirs, plots_dir=plots_dir, model_filename=model_filename)

# %% [markdown]
# ## Preprocess

# %%
params = {
    'preprocess': {
        'get_spec': get_spec,
        'max_dur': 0.2, # maximum syllable duration
        'min_freq': 10e3, # minimum frequency
        'max_freq': 100e3, # maximum frequency
        'num_freq_bins': X_SHAPE[0], # hard-coded
        'num_time_bins': X_SHAPE[1], # hard-coded
        'nperseg': 1024, # FFT
        'noverlap': 512, # FFT
        'spec_min_val': 1.5, # minimum log-spectrogram value
        'spec_noise_thres': 2.5, # if no value in spectogram is above this, co
        'spec_max_val': 4.5, # maximum log-spectrogram value
        'fs': 250000, # audio samplerate
        'mel': False, # frequency spacing, mel or linear
        'time_stretch': True, # stretch short syllables?
        'within_syll_normalize': True, # normalize spectrogram values on a
                                        # spectrogram-by-spectrogram basis
        'normalize_quantile': 0.0, # throw away values below this quantile
        'max_num_syllables': None, # maximum number of syllables per directory
        'sylls_per_file': 1, # syllable per file
        'sigma': 1,
        'flip': False,
        'notch_filter': False, # whether to apply notch filter for 60 kHz noise
        'fn': 54e3, # frequency of notch filter
        'q': 30, # quality factor
        'real_preprocess_params': ('min_freq', 'max_freq', 'spec_min_val', \
                'spec_max_val', 'max_dur'), # tunable parameters
        'int_preprocess_params': ('nperseg','noverlap'), # tunable parameters
        'binary_preprocess_params': ('time_stretch', 'mel', \
                'within_syll_normalize'), # tunable parameters
    },
}

# %%
n_jobs = os.cpu_count()-1
gen = zip(audio_dirs, seg_dirs, spec_dirs, repeat(params['preprocess']))
Parallel(n_jobs=n_jobs)(delayed(process_sylls)(*args) for args in gen)

# %%
onsets = dc.request('onsets')
offsets = dc.request('offsets')
ava_embedding_detections = pd.DataFrame(np.vstack([onsets, offsets]).T, columns=['onsets', 'offsets'])
ava_embedding_detections = ava_embedding_detections.sort_values('onsets',ascending=True)
ava_embedding_detections
# Out:
# Reading field: onsets
# 	Done with: onsets
# Reading field: offsets
# 	Done with: offsets
#            onsets     offsets
# 12160     0.49950     0.57300
# 12161     0.59950     0.68040
# 21356     0.66490     0.74190
# 12162     0.69940     0.78140
# 12163     0.80190     0.87090
# ...           ...         ...
# 8767   3784.29559  3784.35458
# 8768   3784.45457  3784.49856
# 19103  3791.94740  3792.02490
# 19104  3792.48640  3792.54380
# 19105  3792.71430  3792.77180
#
# [23337 rows x 2 columns]

# %%
usvseg_filepaths = glob.glob(os.path.join(root, 'combined detection files', '*_locations.csv'))
usvseg_detections = pd.concat([pd.read_csv(f) for f in usvseg_filepaths], ignore_index=True).rename(columns={'xEnd': 'end'})
usvseg_detections = usvseg_detections.sort_values('start',ascending=True)
usvseg_detections = usvseg_detections[usvseg_detections.code != 6]
offset = 0.015
usvseg_detections['start'] -= offset
usvseg_detections['end'] += offset
origin = {0: 1, 1: 0, 2: 1, 3: 0, 4: 1, 5: 0}
usvseg_detections['Left'] = usvseg_detections['code'].map(origin)
usvseg_detections = usvseg_detections.drop('detection_side', axis=1)
usvseg_detections
# Out:
#        Unnamed: 0      start        end  duration  maxfreq  maxamp  meanfreq  \
# 12897           0     0.4995     0.5730      43.5   33.518  -74.43    33.371
# 12898           1     0.5995     0.6804      51.0   35.249  -73.59    38.586
# 12899           2     0.6649     0.7419      47.0   24.462  -65.25    27.155
# 12900           3     0.6994     0.7814      52.0   26.710  -67.75    36.812
# 12901           4     0.8019     0.8709      39.0   26.129  -58.83    31.683
# ...           ...        ...        ...       ...      ...     ...       ...
# 6037         6037  3775.7858  3775.8318      16.0   20.112  -63.25    21.836
# 6043         6043  3776.8767  3776.9237      17.0   38.245  -62.17    39.073
# 6044         6044  3791.9474  3792.0249      47.5   20.134  -58.69    20.996
# 6045         6045  3792.4864  3792.5438      27.5   20.356  -68.72    22.576
# 6046         6046  3792.7143  3792.7718      27.5   24.009  -71.25    21.751
#
#        cvfreq  in_song  usvseg_index  ...       r_3_y       r_4_x       r_4_y  \
# 12897  0.0732    False             0  ...  138.881461  346.171137  122.701708
# 12898  0.2041    False             1  ...  139.330706  345.351129  125.206485
# 12899  0.1779    False             0  ...  140.267890  345.325371  126.199516
# 12900  0.3191    False             2  ...  140.591894  345.016189  126.852271
# 12901  0.2641    False             3  ...  141.016699  344.934351  128.655562
# ...       ...      ...           ...  ...         ...         ...         ...
# 6037   0.0644    False          3525  ...  259.526129  361.631232  248.044911
# 6043   0.0300    False          4664  ...  260.778644  361.024796  245.537210
# 6044   0.0575    False          4666  ...         NaN         NaN         NaN
# 6045   0.0815    False          4667  ...         NaN         NaN         NaN
# 6046   0.0658    False          4668  ...         NaN         NaN         NaN
#
#             r_5_x       r_5_y       r_6_x       r_6_y  hour  \
# 12897  356.390433  111.148986  367.034968  100.514674     2
# 12898  355.580691  112.454785  367.640277  102.192295     2
# 12899  355.556774  113.738124  368.286718  103.502654     2
# 12900  355.217769  114.697781  368.286638  105.112831     2
# 12901  355.560531  117.130088  370.816151  110.737177     2
# ...           ...         ...         ...         ...   ...
# 6037   347.613934  240.498409  341.226128  231.621510     0
# 6043   346.337154  240.465739  334.910936  237.945167     0
# 6044          NaN         NaN         NaN         NaN     0
# 6045          NaN         NaN         NaN         NaN     0
# 6046          NaN         NaN         NaN         NaN     0
#
#                       time  Left
# 12897  2022-12-08 12:57:57     0
# 12898  2022-12-08 12:57:57     0
# 12899  2022-12-08 12:57:57     1
# 12900  2022-12-08 12:57:57     0
# 12901  2022-12-08 12:57:57     0
# ...                    ...   ...
# 6037   2022-12-08 10:52:25     0
# 6043   2022-12-08 10:52:25     1
# 6044   2022-12-08 10:52:25     1
# 6045   2022-12-08 10:52:25     1
# 6046   2022-12-08 10:52:25     1
#
# [18640 rows x 40 columns]

# %%
song_filepaths = glob.glob(os.path.join(root, 'song detection files', '*_locations.csv'))
song_detections = pd.concat([pd.read_csv(f) for f in song_filepaths], ignore_index=True)
song_detections = song_detections.sort_values('start',ascending=True)
side = {'l':1, 'r':0}
song_detections['Left'] = song_detections['source'].map(side)
song_detections = song_detections.drop('source', axis=1)
song_detections
# Out:
#         #        start          end  duration  song_idx       l_1_x  \
# 2004    0     1.668804     1.686802  0.017998         0  277.475870
# 947     0    75.461669    75.473667  0.011999         0  274.340842
# 948     1    75.548658    75.561657  0.012998         0  274.306959
# 949     2    75.714638    75.727637  0.012998         0  274.305464
# 950     3    75.741635    75.755633  0.013998         0  273.120568
# ...   ...          ...          ...       ...       ...         ...
# 942   942  3783.891637  3783.951630  0.059993        12  266.824083
# 943   943  3784.023621  3784.086614  0.062992        12  267.158574
# 944   944  3784.160605  3784.220598  0.059993        12  269.353676
# 945   945  3784.295589  3784.354581  0.058993        12  269.070331
# 946   946  3784.454569  3784.498564  0.043995        12  269.261292
#
#            l_1_y       l_2_x       l_2_y       l_3_x  ...       r_3_y  \
# 2004  124.086723  265.513814  144.267367  289.444058  ...  141.813165
# 947   203.563430  280.621399  227.523872  298.193699  ...  213.410980
# 948   203.541976  278.084473  227.559155  298.173519  ...  213.440327
# 949   203.570065  278.087578  227.572733  298.159874  ...  213.420018
# 950   203.575236  278.066018  227.579165  298.159203  ...  213.403902
# ...          ...         ...         ...         ...  ...         ...
# 942   249.079578  236.678971  251.888873  286.609501  ...  268.679964
# 943   250.307073  248.365966  255.505798  287.546609  ...  268.015684
# 944   249.376027  254.058380  254.747772  289.795969  ...  267.391566
# 945   249.071061  254.368548  254.737409  290.734595  ...  268.028284
# 946   249.073522  261.200398  261.212428  290.549332  ...  266.250072
#
#            r_4_x       r_4_y       r_5_x       r_5_y       r_6_x       r_6_y  \
# 2004  345.369169  130.364942  358.084026  120.147029  373.369943  112.495091
# 947   345.359810  200.656331  360.604577  189.148283  375.959135  178.929658
# 948   344.695769  200.668791  359.350282  189.774713  375.898824  180.178736
# 949   344.113471  201.884115  359.998850  190.433075  377.199647  180.182538
# 950   344.113796  200.702175  359.388655  190.446227  377.162420  180.210364
# ...          ...         ...         ...         ...         ...         ...
# 942   346.976788  256.318619  338.689713  245.549012  344.110474  232.502373
# 943   346.661851  256.908301  338.686595  245.557117  343.152071  232.844127
# 944   345.399253  256.305443  337.739086  245.546384  342.857008  232.843338
# 945   346.640033  255.682495  338.689555  245.548073  343.795232  232.820272
# 946   344.239997  255.640257  336.157744  246.803809  344.229905  231.987125
#
#       hour                 time  Left
# 2004     2  2022-12-08 12:57:57     1
# 947      1  2022-12-08 11:56:06     1
# 948      1  2022-12-08 11:56:06     1
# 949      1  2022-12-08 11:56:06     1
# 950      1  2022-12-08 11:56:06     1
# ...    ...                  ...   ...
# 942      0  2022-12-08 10:52:25     1
# 943      0  2022-12-08 10:52:25     1
# 944      0  2022-12-08 10:52:25     1
# 945      0  2022-12-08 10:52:25     1
# 946      0  2022-12-08 10:52:25     1
#
# [3197 rows x 32 columns]

# %%
detections_locations_all = pd.concat([usvseg_detections,song_detections],axis=0)
detections_locations_all = detections_locations_all.sort_values('start',ascending=True)
detections_locations_all
# Out:
#        Unnamed: 0        start          end   duration  maxfreq  maxamp  \
# 12897         0.0     0.499500     0.573000  43.500000   33.518  -74.43
# 12898         1.0     0.599500     0.680400  51.000000   35.249  -73.59
# 12899         2.0     0.664900     0.741900  47.000000   24.462  -65.25
# 12900         3.0     0.699400     0.781400  52.000000   26.710  -67.75
# 12901         4.0     0.801900     0.870900  39.000000   26.129  -58.83
# ...           ...          ...          ...        ...      ...     ...
# 945           NaN  3784.295589  3784.354581   0.058993      NaN     NaN
# 946           NaN  3784.454569  3784.498564   0.043995      NaN     NaN
# 6044       6044.0  3791.947400  3792.024900  47.500000   20.134  -58.69
# 6045       6045.0  3792.486400  3792.543800  27.500000   20.356  -68.72
# 6046       6046.0  3792.714300  3792.771800  27.500000   24.009  -71.25
#
#        meanfreq  cvfreq in_song  usvseg_index  ...       r_4_y       r_5_x  \
# 12897    33.371  0.0732   False           0.0  ...  122.701708  356.390433
# 12898    38.586  0.2041   False           1.0  ...  125.206485  355.580691
# 12899    27.155  0.1779   False           0.0  ...  126.199516  355.556774
# 12900    36.812  0.3191   False           2.0  ...  126.852271  355.217769
# 12901    31.683  0.2641   False           3.0  ...  128.655562  355.560531
# ...         ...     ...     ...           ...  ...         ...         ...
# 945         NaN     NaN     NaN           NaN  ...  255.682495  338.689555
# 946         NaN     NaN     NaN           NaN  ...  255.640257  336.157744
# 6044     20.996  0.0575   False        4666.0  ...         NaN         NaN
# 6045     22.576  0.0815   False        4667.0  ...         NaN         NaN
# 6046     21.751  0.0658   False        4668.0  ...         NaN         NaN
#
#             r_5_y       r_6_x       r_6_y  hour                 time  Left  \
# 12897  111.148986  367.034968  100.514674     2  2022-12-08 12:57:57     0
# 12898  112.454785  367.640277  102.192295     2  2022-12-08 12:57:57     0
# 12899  113.738124  368.286718  103.502654     2  2022-12-08 12:57:57     1
# 12900  114.697781  368.286638  105.112831     2  2022-12-08 12:57:57     0
# 12901  117.130088  370.816151  110.737177     2  2022-12-08 12:57:57     0
# ...           ...         ...         ...   ...                  ...   ...
# 945    245.548073  343.795232  232.820272     0  2022-12-08 10:52:25     1
# 946    246.803809  344.229905  231.987125     0  2022-12-08 10:52:25     1
# 6044          NaN         NaN         NaN     0  2022-12-08 10:52:25     1
# 6045          NaN         NaN         NaN     0  2022-12-08 10:52:25     1
# 6046          NaN         NaN         NaN     0  2022-12-08 10:52:25     1
#
#            #  song_idx
# 12897    NaN       NaN
# 12898    NaN       NaN
# 12899    NaN       NaN
# 12900    NaN       NaN
# 12901    NaN       NaN
# ...      ...       ...
# 945    945.0      12.0
# 946    946.0      12.0
# 6044     NaN       NaN
# 6045     NaN       NaN
# 6046     NaN       NaN
#
# [21837 rows x 42 columns]

# %%
offset = 0
usvseg_detections.reset_index(drop=True, inplace=True)
for i in range(detections_locations_all.shape[0]):
    ava_onset = ava_embedding_detections.iloc[i,0]
    usvseg_onset = detections_locations_all.iloc[i,1]
    if abs(ava_onset+offset-usvseg_onset)>1e-3:
        #detections_locations_all.drop(i, inplace=True)
        ava_embedding_detections.drop(ava_embedding_detections.index[i], inplace=True)
        print(f'ava detection {i} not matching with usvseg detection {i}')
        i-=1
# Out:
# ava detection 15 not matching with usvseg detection 15
# ava detection 22 not matching with usvseg detection 22
# ava detection 28 not matching with usvseg detection 28
# ava detection 36 not matching with usvseg detection 36
# ava detection 39 not matching with usvseg detection 39
# ava detection 47 not matching with usvseg detection 47
# ava detection 48 not matching with usvseg detection 48
# ava detection 49 not matching with usvseg detection 49
# ava detection 50 not matching with usvseg detection 50
# ava detection 51 not matching with usvseg detection 51
# ava detection 52 not matching with usvseg detection 52
# ava detection 53 not matching with usvseg detection 53
# ava detection 54 not matching with usvseg detection 54
# ava detection 55 not matching with usvseg detection 55
# ava detection 56 not matching with usvseg detection 56
# ava detection 57 not matching with usvseg detection 57
# ava detection 58 not matching with usvseg detection 58
# ava detection 59 not matching with usvseg detection 59
# ava detection 60 not matching with usvseg detection 60
# ava detection 61 not matching with usvseg detection 61
# ava detection 62 not matching with usvseg detection 62
# ava detection 63 not matching with usvseg detection 63
# ava detection 64 not matching with usvseg detection 64
# ava detection 65 not matching with usvseg detection 65
# ava detection 66 not matching with usvseg detection 66
# ava detection 67 not matching with usvseg detection 67
# ava detection 68 not matching with usvseg detection 68
# ava detection 69 not matching with usvseg detection 69
# ava detection 70 not matching with usvseg detection 70
# ava detection 80 not matching with usvseg detection 80
# ava detection 83 not matching with usvseg detection 83
# ava detection 98 not matching with usvseg detection 98
# ava detection 107 not matching with usvseg detection 107
# ava detection 109 not matching with usvseg detection 109
# ava detection 110 not matching with usvseg detection 110
# ava detection 111 not matching with usvseg detection 111
# ava detection 112 not matching with usvseg detection 112
# ava detection 113 not matching with usvseg detection 113
# ava detection 114 not matching with usvseg detection 114
# ava detection 115 not matching with usvseg detection 115
# ava detection 201 not matching with usvseg detection 201
# ava detection 234 not matching with usvseg detection 234
# ava detection 314 not matching with usvseg detection 314
# ava detection 365 not matching with usvseg detection 365
# ava detection 370 not matching with usvseg detection 370
# ava detection 381 not matching with usvseg detection 381
# ava detection 383 not matching with usvseg detection 383
# ava detection 386 not matching with usvseg detection 386
# ava detection 394 not matching with usvseg detection 394
# ava detection 401 not matching with usvseg detection 401
# ava detection 405 not matching with usvseg detection 405
# ava detection 414 not matching with usvseg detection 414
# ava detection 416 not matching with usvseg detection 416
# ava detection 489 not matching with usvseg detection 489
# ava detection 490 not matching with usvseg detection 490
# ava detection 498 not matching with usvseg detection 498
# ava detection 513 not matching with usvseg detection 513
# ava detection 521 not matching with usvseg detection 521
# ava detection 524 not matching with usvseg detection 524
# ava detection 525 not matching with usvseg detection 525
# ava detection 526 not matching with usvseg detection 526
# ava detection 527 not matching with usvseg detection 527
# ava detection 528 not matching with usvseg detection 528
# ava detection 529 not matching with usvseg detection 529
# ava detection 530 not matching with usvseg detection 530
# ava detection 531 not matching with usvseg detection 531
# ava detection 532 not matching with usvseg detection 532
# ava detection 533 not matching with usvseg detection 533
# ava detection 534 not matching with usvseg detection 534
# ava detection 535 not matching with usvseg detection 535
# ava detection 536 not matching with usvseg detection 536
# ava detection 537 not matching with usvseg detection 537
# ava detection 538 not matching with usvseg detection 538
# ava detection 539 not matching with usvseg detection 539
# ava detection 540 not matching with usvseg detection 540
# ava detection 541 not matching with usvseg detection 541
# ava detection 542 not matching with usvseg detection 542
# ava detection 543 not matching with usvseg detection 543
# ava detection 544 not matching with usvseg detection 544
# ava detection 545 not matching with usvseg detection 545
# ava detection 546 not matching with usvseg detection 546
# ava detection 619 not matching with usvseg detection 619
# ava detection 630 not matching with usvseg detection 630
# ava detection 649 not matching with usvseg detection 649
# ava detection 650 not matching with usvseg detection 650
# ava detection 662 not matching with usvseg detection 662
# ava detection 681 not matching with usvseg detection 681
# ava detection 712 not matching with usvseg detection 712
# ava detection 714 not matching with usvseg detection 714
# ava detection 739 not matching with usvseg detection 739
# ava detection 759 not matching with usvseg detection 759
# ava detection 763 not matching with usvseg detection 763
# ava detection 768 not matching with usvseg detection 768
# ava detection 790 not matching with usvseg detection 790
# ava detection 791 not matching with usvseg detection 791
# ava detection 812 not matching with usvseg detection 812
# ava detection 813 not matching with usvseg detection 813
# ava detection 817 not matching with usvseg detection 817
# ava detection 818 not matching with usvseg detection 818
# ava detection 819 not matching with usvseg detection 819
# ava detection 820 not matching with usvseg detection 820
# ava detection 845 not matching with usvseg detection 845
# ava detection 870 not matching with usvseg detection 870
# ava detection 903 not matching with usvseg detection 903
# ava detection 909 not matching with usvseg detection 909
# ava detection 912 not matching with usvseg detection 912
# ava detection 930 not matching with usvseg detection 930
# ava detection 950 not matching with usvseg detection 950
# ava detection 953 not matching with usvseg detection 953
# ava detection 962 not matching with usvseg detection 962
# ava detection 992 not matching with usvseg detection 992
# ava detection 1018 not matching with usvseg detection 1018
# ava detection 1067 not matching with usvseg detection 1067
# ava detection 1078 not matching with usvseg detection 1078
# ava detection 1083 not matching with usvseg detection 1083
# ava detection 1123 not matching with usvseg detection 1123
# ava detection 1127 not matching with usvseg detection 1127
# ava detection 1205 not matching with usvseg detection 1205
# ava detection 1215 not matching with usvseg detection 1215
# ava detection 1222 not matching with usvseg detection 1222
# ava detection 1233 not matching with usvseg detection 1233
# ava detection 1236 not matching with usvseg detection 1236
# ava detection 1240 not matching with usvseg detection 1240
# ava detection 1247 not matching with usvseg detection 1247
# ava detection 1249 not matching with usvseg detection 1249
# ava detection 1260 not matching with usvseg detection 1260
# ava detection 1385 not matching with usvseg detection 1385
# ava detection 1396 not matching with usvseg detection 1396
# ava detection 1409 not matching with usvseg detection 1409
# ava detection 1414 not matching with usvseg detection 1414
# ava detection 1446 not matching with usvseg detection 1446
# ava detection 1447 not matching with usvseg detection 1447
# ava detection 1451 not matching with usvseg detection 1451
# ava detection 1475 not matching with usvseg detection 1475
# ava detection 1479 not matching with usvseg detection 1479
# ava detection 1532 not matching with usvseg detection 1532
# ava detection 1575 not matching with usvseg detection 1575
# ava detection 1601 not matching with usvseg detection 1601
# ava detection 1614 not matching with usvseg detection 1614
# ava detection 1616 not matching with usvseg detection 1616
# ava detection 1621 not matching with usvseg detection 1621
# ava detection 1622 not matching with usvseg detection 1622
# ava detection 1624 not matching with usvseg detection 1624
# ava detection 1650 not matching with usvseg detection 1650
# ava detection 1653 not matching with usvseg detection 1653
# ava detection 1658 not matching with usvseg detection 1658
# ava detection 1676 not matching with usvseg detection 1676
# ava detection 1710 not matching with usvseg detection 1710
# ava detection 1764 not matching with usvseg detection 1764
# ava detection 1784 not matching with usvseg detection 1784
# ava detection 1806 not matching with usvseg detection 1806
# ava detection 1864 not matching with usvseg detection 1864
# ava detection 1869 not matching with usvseg detection 1869
# ava detection 1882 not matching with usvseg detection 1882
# ava detection 1910 not matching with usvseg detection 1910
# ava detection 1939 not matching with usvseg detection 1939
# ava detection 1963 not matching with usvseg detection 1963
# ava detection 1990 not matching with usvseg detection 1990
# ava detection 2003 not matching with usvseg detection 2003
# ava detection 2045 not matching with usvseg detection 2045
# ava detection 2051 not matching with usvseg detection 2051
# ava detection 2076 not matching with usvseg detection 2076
# ava detection 2190 not matching with usvseg detection 2190
# ava detection 2202 not matching with usvseg detection 2202
# ava detection 2244 not matching with usvseg detection 2244
# ava detection 2261 not matching with usvseg detection 2261
# ava detection 2267 not matching with usvseg detection 2267
# ava detection 2270 not matching with usvseg detection 2270
# ava detection 2283 not matching with usvseg detection 2283
# ava detection 2304 not matching with usvseg detection 2304
# ava detection 2306 not matching with usvseg detection 2306
# ava detection 2314 not matching with usvseg detection 2314
# ava detection 2328 not matching with usvseg detection 2328
# ava detection 2357 not matching with usvseg detection 2357
# ava detection 2391 not matching with usvseg detection 2391
# ava detection 2408 not matching with usvseg detection 2408
# ava detection 2418 not matching with usvseg detection 2418
# ava detection 2432 not matching with usvseg detection 2432
# ava detection 2454 not matching with usvseg detection 2454
# ava detection 2457 not matching with usvseg detection 2457
# ava detection 2461 not matching with usvseg detection 2461
# ava detection 2517 not matching with usvseg detection 2517
# ava detection 2605 not matching with usvseg detection 2605
# ava detection 2626 not matching with usvseg detection 2626
# ava detection 2644 not matching with usvseg detection 2644
# ava detection 2665 not matching with usvseg detection 2665
# ava detection 2671 not matching with usvseg detection 2671
# ava detection 2710 not matching with usvseg detection 2710
# ava detection 2712 not matching with usvseg detection 2712
# ava detection 2727 not matching with usvseg detection 2727
# ava detection 2743 not matching with usvseg detection 2743
# ava detection 2756 not matching with usvseg detection 2756
# ava detection 2770 not matching with usvseg detection 2770
# ava detection 2791 not matching with usvseg detection 2791
# ava detection 2805 not matching with usvseg detection 2805
# ava detection 2813 not matching with usvseg detection 2813
# ava detection 2843 not matching with usvseg detection 2843
# ava detection 2849 not matching with usvseg detection 2849
# ava detection 2850 not matching with usvseg detection 2850
# ava detection 2875 not matching with usvseg detection 2875
# ava detection 2876 not matching with usvseg detection 2876
# ava detection 2889 not matching with usvseg detection 2889
# ava detection 2895 not matching with usvseg detection 2895
# ava detection 2941 not matching with usvseg detection 2941
# ava detection 2952 not matching with usvseg detection 2952
# ava detection 2961 not matching with usvseg detection 2961
# ava detection 2968 not matching with usvseg detection 2968
# ava detection 2970 not matching with usvseg detection 2970
# ava detection 2986 not matching with usvseg detection 2986
# ava detection 2987 not matching with usvseg detection 2987
# ava detection 2998 not matching with usvseg detection 2998
# ava detection 3032 not matching with usvseg detection 3032
# ava detection 3100 not matching with usvseg detection 3100
# ava detection 3149 not matching with usvseg detection 3149
# ava detection 3221 not matching with usvseg detection 3221
# ava detection 3272 not matching with usvseg detection 3272
# ava detection 3342 not matching with usvseg detection 3342
# ava detection 3366 not matching with usvseg detection 3366
# ava detection 3689 not matching with usvseg detection 3689
# ava detection 3748 not matching with usvseg detection 3748
# ava detection 3783 not matching with usvseg detection 3783
# ava detection 3871 not matching with usvseg detection 3871
# ava detection 3902 not matching with usvseg detection 3902
# ava detection 3907 not matching with usvseg detection 3907
# ava detection 3936 not matching with usvseg detection 3936
# ava detection 3997 not matching with usvseg detection 3997
# ava detection 4014 not matching with usvseg detection 4014
# ava detection 4022 not matching with usvseg detection 4022
# ava detection 4023 not matching with usvseg detection 4023
# ava detection 4025 not matching with usvseg detection 4025
# ava detection 4026 not matching with usvseg detection 4026
# ava detection 4032 not matching with usvseg detection 4032
# ava detection 4045 not matching with usvseg detection 4045
# ava detection 4046 not matching with usvseg detection 4046
# ava detection 4092 not matching with usvseg detection 4092
# ava detection 4101 not matching with usvseg detection 4101
# ava detection 4141 not matching with usvseg detection 4141
# ava detection 4148 not matching with usvseg detection 4148
# ava detection 4156 not matching with usvseg detection 4156
# ava detection 4158 not matching with usvseg detection 4158
# ava detection 4162 not matching with usvseg detection 4162
# ava detection 4168 not matching with usvseg detection 4168
# ava detection 4178 not matching with usvseg detection 4178
# ava detection 4181 not matching with usvseg detection 4181
# ava detection 4185 not matching with usvseg detection 4185
# ava detection 4223 not matching with usvseg detection 4223
# ava detection 4225 not matching with usvseg detection 4225
# ava detection 4228 not matching with usvseg detection 4228
# ava detection 4229 not matching with usvseg detection 4229
# ava detection 4239 not matching with usvseg detection 4239
# ava detection 4261 not matching with usvseg detection 4261
# ava detection 4266 not matching with usvseg detection 4266
# ava detection 4270 not matching with usvseg detection 4270
# ava detection 4283 not matching with usvseg detection 4283
# ava detection 4284 not matching with usvseg detection 4284
# ava detection 4289 not matching with usvseg detection 4289
# ava detection 4296 not matching with usvseg detection 4296
# ava detection 4305 not matching with usvseg detection 4305
# ava detection 4306 not matching with usvseg detection 4306
# ava detection 4310 not matching with usvseg detection 4310
# ava detection 4376 not matching with usvseg detection 4376
# ava detection 4392 not matching with usvseg detection 4392
# ava detection 4403 not matching with usvseg detection 4403
# ava detection 4443 not matching with usvseg detection 4443
# ava detection 4460 not matching with usvseg detection 4460
# ava detection 4465 not matching with usvseg detection 4465
# ava detection 4523 not matching with usvseg detection 4523
# ava detection 4541 not matching with usvseg detection 4541
# ava detection 4577 not matching with usvseg detection 4577
# ava detection 4662 not matching with usvseg detection 4662
# ava detection 4663 not matching with usvseg detection 4663
# ava detection 4705 not matching with usvseg detection 4705
# ava detection 4716 not matching with usvseg detection 4716
# ava detection 4742 not matching with usvseg detection 4742
# ava detection 4791 not matching with usvseg detection 4791
# ava detection 4792 not matching with usvseg detection 4792
# ava detection 4796 not matching with usvseg detection 4796
# ava detection 4797 not matching with usvseg detection 4797
# ava detection 4835 not matching with usvseg detection 4835
# ava detection 4857 not matching with usvseg detection 4857
# ava detection 4881 not matching with usvseg detection 4881
# ava detection 4899 not matching with usvseg detection 4899
# ava detection 4900 not matching with usvseg detection 4900
# ava detection 4922 not matching with usvseg detection 4922
# ava detection 4940 not matching with usvseg detection 4940
# ava detection 4972 not matching with usvseg detection 4972
# ava detection 5005 not matching with usvseg detection 5005
# ava detection 5036 not matching with usvseg detection 5036
# ava detection 5043 not matching with usvseg detection 5043
# ava detection 5045 not matching with usvseg detection 5045
# ava detection 5098 not matching with usvseg detection 5098
# ava detection 5107 not matching with usvseg detection 5107
# ava detection 5116 not matching with usvseg detection 5116
# ava detection 5183 not matching with usvseg detection 5183
# ava detection 5184 not matching with usvseg detection 5184
# ava detection 5187 not matching with usvseg detection 5187
# ava detection 5202 not matching with usvseg detection 5202
# ava detection 5205 not matching with usvseg detection 5205
# ava detection 5217 not matching with usvseg detection 5217
# ava detection 5309 not matching with usvseg detection 5309
# ava detection 5340 not matching with usvseg detection 5340
# ava detection 5357 not matching with usvseg detection 5357
# ava detection 5359 not matching with usvseg detection 5359
# ava detection 5471 not matching with usvseg detection 5471
# ava detection 5490 not matching with usvseg detection 5490
# ava detection 5496 not matching with usvseg detection 5496
# ava detection 5502 not matching with usvseg detection 5502
# ava detection 5615 not matching with usvseg detection 5615
# ava detection 5630 not matching with usvseg detection 5630
# ava detection 5654 not matching with usvseg detection 5654
# ava detection 5671 not matching with usvseg detection 5671
# ava detection 5674 not matching with usvseg detection 5674
# ava detection 5698 not matching with usvseg detection 5698
# ava detection 5700 not matching with usvseg detection 5700
# ava detection 5748 not matching with usvseg detection 5748
# ava detection 5764 not matching with usvseg detection 5764
# ava detection 5781 not matching with usvseg detection 5781
# ava detection 5790 not matching with usvseg detection 5790
# ava detection 5811 not matching with usvseg detection 5811
# ava detection 5825 not matching with usvseg detection 5825
# ava detection 5832 not matching with usvseg detection 5832
# ava detection 5833 not matching with usvseg detection 5833
# ava detection 5843 not matching with usvseg detection 5843
# ava detection 5846 not matching with usvseg detection 5846
# ava detection 5867 not matching with usvseg detection 5867
# ava detection 5897 not matching with usvseg detection 5897
# ava detection 5908 not matching with usvseg detection 5908
# ava detection 5936 not matching with usvseg detection 5936
# ava detection 5991 not matching with usvseg detection 5991
# ava detection 6006 not matching with usvseg detection 6006
# ava detection 6007 not matching with usvseg detection 6007
# ava detection 6010 not matching with usvseg detection 6010
# ava detection 6078 not matching with usvseg detection 6078
# ava detection 6102 not matching with usvseg detection 6102
# ava detection 6119 not matching with usvseg detection 6119
# ava detection 6120 not matching with usvseg detection 6120
# ava detection 6126 not matching with usvseg detection 6126
# ava detection 6134 not matching with usvseg detection 6134
# ava detection 6154 not matching with usvseg detection 6154
# ava detection 6164 not matching with usvseg detection 6164
# ava detection 6173 not matching with usvseg detection 6173
# ava detection 6174 not matching with usvseg detection 6174
# ava detection 6229 not matching with usvseg detection 6229
# ava detection 6240 not matching with usvseg detection 6240
# ava detection 6254 not matching with usvseg detection 6254
# ava detection 6273 not matching with usvseg detection 6273
# ava detection 6298 not matching with usvseg detection 6298
# ava detection 6347 not matching with usvseg detection 6347
# ava detection 6393 not matching with usvseg detection 6393
# ava detection 6426 not matching with usvseg detection 6426
# ava detection 6479 not matching with usvseg detection 6479
# ava detection 6480 not matching with usvseg detection 6480
# ava detection 6516 not matching with usvseg detection 6516
# ava detection 6558 not matching with usvseg detection 6558
# ava detection 6570 not matching with usvseg detection 6570
# ava detection 6601 not matching with usvseg detection 6601
# ava detection 6605 not matching with usvseg detection 6605
# ava detection 6617 not matching with usvseg detection 6617
# ava detection 6649 not matching with usvseg detection 6649
# ava detection 6658 not matching with usvseg detection 6658
# ava detection 6659 not matching with usvseg detection 6659
# ava detection 6673 not matching with usvseg detection 6673
# ava detection 6674 not matching with usvseg detection 6674
# ava detection 6675 not matching with usvseg detection 6675
# ava detection 6679 not matching with usvseg detection 6679
# ava detection 6684 not matching with usvseg detection 6684
# ava detection 6707 not matching with usvseg detection 6707
# ava detection 6730 not matching with usvseg detection 6730
# ava detection 6756 not matching with usvseg detection 6756
# ava detection 6777 not matching with usvseg detection 6777
# ava detection 6779 not matching with usvseg detection 6779
# ava detection 6832 not matching with usvseg detection 6832
# ava detection 6849 not matching with usvseg detection 6849
# ava detection 6907 not matching with usvseg detection 6907
# ava detection 6909 not matching with usvseg detection 6909
# ava detection 6910 not matching with usvseg detection 6910
# ava detection 6911 not matching with usvseg detection 6911
# ava detection 6912 not matching with usvseg detection 6912
# ava detection 6922 not matching with usvseg detection 6922
# ava detection 6988 not matching with usvseg detection 6988
# ava detection 6995 not matching with usvseg detection 6995
# ava detection 7002 not matching with usvseg detection 7002
# ava detection 7003 not matching with usvseg detection 7003
# ava detection 7004 not matching with usvseg detection 7004
# ava detection 7007 not matching with usvseg detection 7007
# ava detection 7008 not matching with usvseg detection 7008
# ava detection 7009 not matching with usvseg detection 7009
# ava detection 7018 not matching with usvseg detection 7018
# ava detection 7031 not matching with usvseg detection 7031
# ava detection 7037 not matching with usvseg detection 7037
# ava detection 7039 not matching with usvseg detection 7039
# ava detection 7049 not matching with usvseg detection 7049
# ava detection 7060 not matching with usvseg detection 7060
# ava detection 7101 not matching with usvseg detection 7101
# ava detection 7102 not matching with usvseg detection 7102
# ava detection 7105 not matching with usvseg detection 7105
# ava detection 7111 not matching with usvseg detection 7111
# ava detection 7128 not matching with usvseg detection 7128
# ava detection 7129 not matching with usvseg detection 7129
# ava detection 7130 not matching with usvseg detection 7130
# ava detection 7131 not matching with usvseg detection 7131
# ava detection 7137 not matching with usvseg detection 7137
# ava detection 7146 not matching with usvseg detection 7146
# ava detection 7158 not matching with usvseg detection 7158
# ava detection 7161 not matching with usvseg detection 7161
# ava detection 7162 not matching with usvseg detection 7162
# ava detection 7185 not matching with usvseg detection 7185
# ava detection 7218 not matching with usvseg detection 7218
# ava detection 7312 not matching with usvseg detection 7312
# ava detection 7365 not matching with usvseg detection 7365
# ava detection 7378 not matching with usvseg detection 7378
# ava detection 7380 not matching with usvseg detection 7380
# ava detection 7382 not matching with usvseg detection 7382
# ava detection 7396 not matching with usvseg detection 7396
# ava detection 7412 not matching with usvseg detection 7412
# ava detection 7466 not matching with usvseg detection 7466
# ava detection 7471 not matching with usvseg detection 7471
# ava detection 7485 not matching with usvseg detection 7485
# ava detection 7527 not matching with usvseg detection 7527
# ava detection 7528 not matching with usvseg detection 7528
# ava detection 7574 not matching with usvseg detection 7574
# ava detection 7628 not matching with usvseg detection 7628
# ava detection 7656 not matching with usvseg detection 7656
# ava detection 7661 not matching with usvseg detection 7661
# ava detection 7679 not matching with usvseg detection 7679
# ava detection 7685 not matching with usvseg detection 7685
# ava detection 7696 not matching with usvseg detection 7696
# ava detection 7709 not matching with usvseg detection 7709
# ava detection 7721 not matching with usvseg detection 7721
# ava detection 7723 not matching with usvseg detection 7723
# ava detection 7742 not matching with usvseg detection 7742
# ava detection 7760 not matching with usvseg detection 7760
# ava detection 7777 not matching with usvseg detection 7777
# ava detection 7799 not matching with usvseg detection 7799
# ava detection 7800 not matching with usvseg detection 7800
# ava detection 7801 not matching with usvseg detection 7801
# ava detection 7802 not matching with usvseg detection 7802
# ava detection 7804 not matching with usvseg detection 7804
# ava detection 7806 not matching with usvseg detection 7806
# ava detection 7807 not matching with usvseg detection 7807
# ava detection 7809 not matching with usvseg detection 7809
# ava detection 7810 not matching with usvseg detection 7810
# ava detection 7834 not matching with usvseg detection 7834
# ava detection 7840 not matching with usvseg detection 7840
# ava detection 7845 not matching with usvseg detection 7845
# ava detection 7846 not matching with usvseg detection 7846
# ava detection 7847 not matching with usvseg detection 7847
# ava detection 7848 not matching with usvseg detection 7848
# ava detection 7849 not matching with usvseg detection 7849
# ava detection 7850 not matching with usvseg detection 7850
# ava detection 7851 not matching with usvseg detection 7851
# ava detection 7853 not matching with usvseg detection 7853
# ava detection 7860 not matching with usvseg detection 7860
# ava detection 7864 not matching with usvseg detection 7864
# ava detection 7865 not matching with usvseg detection 7865
# ava detection 7867 not matching with usvseg detection 7867
# ava detection 7876 not matching with usvseg detection 7876
# ava detection 7898 not matching with usvseg detection 7898
# ava detection 7899 not matching with usvseg detection 7899
# ava detection 7904 not matching with usvseg detection 7904
# ava detection 7910 not matching with usvseg detection 7910
# ava detection 7914 not matching with usvseg detection 7914
# ava detection 7925 not matching with usvseg detection 7925
# ava detection 7929 not matching with usvseg detection 7929
# ava detection 7930 not matching with usvseg detection 7930
# ava detection 7934 not matching with usvseg detection 7934
# ava detection 7988 not matching with usvseg detection 7988
# ava detection 8002 not matching with usvseg detection 8002
# ava detection 8012 not matching with usvseg detection 8012
# ava detection 8013 not matching with usvseg detection 8013
# ava detection 8014 not matching with usvseg detection 8014
# ava detection 8015 not matching with usvseg detection 8015
# ava detection 8016 not matching with usvseg detection 8016
# ava detection 8017 not matching with usvseg detection 8017
# ava detection 8018 not matching with usvseg detection 8018
# ava detection 8019 not matching with usvseg detection 8019
# ava detection 8028 not matching with usvseg detection 8028
# ava detection 8033 not matching with usvseg detection 8033
# ava detection 8048 not matching with usvseg detection 8048
# ava detection 8090 not matching with usvseg detection 8090
# ava detection 8098 not matching with usvseg detection 8098
# ava detection 8113 not matching with usvseg detection 8113
# ava detection 8125 not matching with usvseg detection 8125
# ava detection 8126 not matching with usvseg detection 8126
# ava detection 8127 not matching with usvseg detection 8127
# ava detection 8130 not matching with usvseg detection 8130
# ava detection 8142 not matching with usvseg detection 8142
# ava detection 8158 not matching with usvseg detection 8158
# ava detection 8159 not matching with usvseg detection 8159
# ava detection 8193 not matching with usvseg detection 8193
# ava detection 8199 not matching with usvseg detection 8199
# ava detection 8200 not matching with usvseg detection 8200
# ava detection 8208 not matching with usvseg detection 8208
# ava detection 8209 not matching with usvseg detection 8209
# ava detection 8210 not matching with usvseg detection 8210
# ava detection 8215 not matching with usvseg detection 8215
# ava detection 8216 not matching with usvseg detection 8216
# ava detection 8217 not matching with usvseg detection 8217
# ava detection 8218 not matching with usvseg detection 8218
# ava detection 8219 not matching with usvseg detection 8219
# ava detection 8223 not matching with usvseg detection 8223
# ava detection 8224 not matching with usvseg detection 8224
# ava detection 8225 not matching with usvseg detection 8225
# ava detection 8226 not matching with usvseg detection 8226
# ava detection 8227 not matching with usvseg detection 8227
# ava detection 8228 not matching with usvseg detection 8228
# ava detection 8229 not matching with usvseg detection 8229
# ava detection 8230 not matching with usvseg detection 8230
# ava detection 8231 not matching with usvseg detection 8231
# ava detection 8232 not matching with usvseg detection 8232
# ava detection 8233 not matching with usvseg detection 8233
# ava detection 8234 not matching with usvseg detection 8234
# ava detection 8235 not matching with usvseg detection 8235
# ava detection 8236 not matching with usvseg detection 8236
# ava detection 8237 not matching with usvseg detection 8237
# ava detection 8238 not matching with usvseg detection 8238
# ava detection 8239 not matching with usvseg detection 8239
# ava detection 8240 not matching with usvseg detection 8240
# ava detection 8241 not matching with usvseg detection 8241
# ava detection 8242 not matching with usvseg detection 8242
# ava detection 8243 not matching with usvseg detection 8243
# ava detection 8244 not matching with usvseg detection 8244
# ava detection 8245 not matching with usvseg detection 8245
# ava detection 8246 not matching with usvseg detection 8246
# ava detection 8247 not matching with usvseg detection 8247
# ava detection 8248 not matching with usvseg detection 8248
# ava detection 8249 not matching with usvseg detection 8249
# ava detection 8250 not matching with usvseg detection 8250
# ava detection 8251 not matching with usvseg detection 8251
# ava detection 8252 not matching with usvseg detection 8252
# ava detection 8253 not matching with usvseg detection 8253
# ava detection 8254 not matching with usvseg detection 8254
# ava detection 8255 not matching with usvseg detection 8255
# ava detection 8258 not matching with usvseg detection 8258
# ava detection 8263 not matching with usvseg detection 8263
# ava detection 8264 not matching with usvseg detection 8264
# ava detection 8273 not matching with usvseg detection 8273
# ava detection 8277 not matching with usvseg detection 8277
# ava detection 8278 not matching with usvseg detection 8278
# ava detection 8279 not matching with usvseg detection 8279
# ava detection 8280 not matching with usvseg detection 8280
# ava detection 8285 not matching with usvseg detection 8285
# ava detection 8304 not matching with usvseg detection 8304
# ava detection 8353 not matching with usvseg detection 8353
# ava detection 8359 not matching with usvseg detection 8359
# ava detection 8361 not matching with usvseg detection 8361
# ava detection 8373 not matching with usvseg detection 8373
# ava detection 8376 not matching with usvseg detection 8376
# ava detection 8378 not matching with usvseg detection 8378
# ava detection 8387 not matching with usvseg detection 8387
# ava detection 8393 not matching with usvseg detection 8393
# ava detection 8394 not matching with usvseg detection 8394
# ava detection 8395 not matching with usvseg detection 8395
# ava detection 8397 not matching with usvseg detection 8397
# ava detection 8398 not matching with usvseg detection 8398
# ava detection 8399 not matching with usvseg detection 8399
# ava detection 8400 not matching with usvseg detection 8400
# ava detection 8401 not matching with usvseg detection 8401
# ava detection 8402 not matching with usvseg detection 8402
# ava detection 8403 not matching with usvseg detection 8403
# ava detection 8404 not matching with usvseg detection 8404
# ava detection 8405 not matching with usvseg detection 8405
# ava detection 8406 not matching with usvseg detection 8406
# ava detection 8407 not matching with usvseg detection 8407
# ava detection 8408 not matching with usvseg detection 8408
# ava detection 8409 not matching with usvseg detection 8409
# ava detection 8410 not matching with usvseg detection 8410
# ava detection 8418 not matching with usvseg detection 8418
# ava detection 8419 not matching with usvseg detection 8419
# ava detection 8420 not matching with usvseg detection 8420
# ava detection 8451 not matching with usvseg detection 8451
# ava detection 8502 not matching with usvseg detection 8502
# ava detection 8508 not matching with usvseg detection 8508
# ava detection 8530 not matching with usvseg detection 8530
# ava detection 8534 not matching with usvseg detection 8534
# ava detection 8552 not matching with usvseg detection 8552
# ava detection 8569 not matching with usvseg detection 8569
# ava detection 8586 not matching with usvseg detection 8586
# ava detection 8603 not matching with usvseg detection 8603
# ava detection 8604 not matching with usvseg detection 8604
# ava detection 8606 not matching with usvseg detection 8606
# ava detection 8607 not matching with usvseg detection 8607
# ava detection 8613 not matching with usvseg detection 8613
# ava detection 8614 not matching with usvseg detection 8614
# ava detection 8615 not matching with usvseg detection 8615
# ava detection 8616 not matching with usvseg detection 8616
# ava detection 8617 not matching with usvseg detection 8617
# ava detection 8629 not matching with usvseg detection 8629
# ava detection 8635 not matching with usvseg detection 8635
# ava detection 8654 not matching with usvseg detection 8654
# ava detection 8655 not matching with usvseg detection 8655
# ava detection 8656 not matching with usvseg detection 8656
# ava detection 8660 not matching with usvseg detection 8660
# ava detection 8663 not matching with usvseg detection 8663
# ava detection 8718 not matching with usvseg detection 8718
# ava detection 8719 not matching with usvseg detection 8719
# ava detection 8766 not matching with usvseg detection 8766
# ava detection 8767 not matching with usvseg detection 8767
# ava detection 8796 not matching with usvseg detection 8796
# ava detection 8808 not matching with usvseg detection 8808
# ava detection 8814 not matching with usvseg detection 8814
# ava detection 8830 not matching with usvseg detection 8830
# ava detection 8843 not matching with usvseg detection 8843
# ava detection 8882 not matching with usvseg detection 8882
# ava detection 8888 not matching with usvseg detection 8888
# ava detection 8899 not matching with usvseg detection 8899
# ava detection 8900 not matching with usvseg detection 8900
# ava detection 8905 not matching with usvseg detection 8905
# ava detection 8946 not matching with usvseg detection 8946
# ava detection 8973 not matching with usvseg detection 8973
# ava detection 8997 not matching with usvseg detection 8997
# ava detection 9005 not matching with usvseg detection 9005
# ava detection 9007 not matching with usvseg detection 9007
# ava detection 9015 not matching with usvseg detection 9015
# ava detection 9023 not matching with usvseg detection 9023
# ava detection 9024 not matching with usvseg detection 9024
# ava detection 9026 not matching with usvseg detection 9026
# ava detection 9053 not matching with usvseg detection 9053
# ava detection 9070 not matching with usvseg detection 9070
# ava detection 9075 not matching with usvseg detection 9075
# ava detection 9088 not matching with usvseg detection 9088
# ava detection 9090 not matching with usvseg detection 9090
# ava detection 9097 not matching with usvseg detection 9097
# ava detection 9104 not matching with usvseg detection 9104
# ava detection 9115 not matching with usvseg detection 9115
# ava detection 9149 not matching with usvseg detection 9149
# ava detection 9189 not matching with usvseg detection 9189
# ava detection 9211 not matching with usvseg detection 9211
# ava detection 9288 not matching with usvseg detection 9288
# ava detection 9305 not matching with usvseg detection 9305
# ava detection 9358 not matching with usvseg detection 9358
# ava detection 9402 not matching with usvseg detection 9402
# ava detection 9427 not matching with usvseg detection 9427
# ava detection 9450 not matching with usvseg detection 9450
# ava detection 9465 not matching with usvseg detection 9465
# ava detection 9466 not matching with usvseg detection 9466
# ava detection 9521 not matching with usvseg detection 9521
# ava detection 9590 not matching with usvseg detection 9590
# ava detection 9602 not matching with usvseg detection 9602
# ava detection 9698 not matching with usvseg detection 9698
# ava detection 9756 not matching with usvseg detection 9756
# ava detection 9769 not matching with usvseg detection 9769
# ava detection 9807 not matching with usvseg detection 9807
# ava detection 9826 not matching with usvseg detection 9826
# ava detection 9896 not matching with usvseg detection 9896
# ava detection 9903 not matching with usvseg detection 9903
# ava detection 9919 not matching with usvseg detection 9919
# ava detection 9923 not matching with usvseg detection 9923
# ava detection 9925 not matching with usvseg detection 9925
# ava detection 9959 not matching with usvseg detection 9959
# ava detection 9987 not matching with usvseg detection 9987
# ava detection 10005 not matching with usvseg detection 10005
# ava detection 10041 not matching with usvseg detection 10041
# ava detection 10070 not matching with usvseg detection 10070
# ava detection 10098 not matching with usvseg detection 10098
# ava detection 10119 not matching with usvseg detection 10119
# ava detection 10148 not matching with usvseg detection 10148
# ava detection 10157 not matching with usvseg detection 10157
# ava detection 10158 not matching with usvseg detection 10158
# ava detection 10260 not matching with usvseg detection 10260
# ava detection 10295 not matching with usvseg detection 10295
# ava detection 10297 not matching with usvseg detection 10297
# ava detection 10302 not matching with usvseg detection 10302
# ava detection 10312 not matching with usvseg detection 10312
# ava detection 10363 not matching with usvseg detection 10363
# ava detection 10364 not matching with usvseg detection 10364
# ava detection 10367 not matching with usvseg detection 10367
# ava detection 10375 not matching with usvseg detection 10375
# ava detection 10387 not matching with usvseg detection 10387
# ava detection 10402 not matching with usvseg detection 10402
# ava detection 10412 not matching with usvseg detection 10412
# ava detection 10426 not matching with usvseg detection 10426
# ava detection 10486 not matching with usvseg detection 10486
# ava detection 10487 not matching with usvseg detection 10487
# ava detection 10501 not matching with usvseg detection 10501
# ava detection 10505 not matching with usvseg detection 10505
# ava detection 10507 not matching with usvseg detection 10507
# ava detection 10607 not matching with usvseg detection 10607
# ava detection 10634 not matching with usvseg detection 10634
# ava detection 10750 not matching with usvseg detection 10750
# ava detection 10796 not matching with usvseg detection 10796
# ava detection 10839 not matching with usvseg detection 10839
# ava detection 10845 not matching with usvseg detection 10845
# ava detection 10853 not matching with usvseg detection 10853
# ava detection 10860 not matching with usvseg detection 10860
# ava detection 10866 not matching with usvseg detection 10866
# ava detection 10876 not matching with usvseg detection 10876
# ava detection 10909 not matching with usvseg detection 10909
# ava detection 11004 not matching with usvseg detection 11004
# ava detection 11007 not matching with usvseg detection 11007
# ava detection 11013 not matching with usvseg detection 11013
# ava detection 11064 not matching with usvseg detection 11064
# ava detection 11071 not matching with usvseg detection 11071
# ava detection 11090 not matching with usvseg detection 11090
# ava detection 11146 not matching with usvseg detection 11146
# ava detection 11165 not matching with usvseg detection 11165
# ava detection 11168 not matching with usvseg detection 11168
# ava detection 11174 not matching with usvseg detection 11174
# ava detection 11203 not matching with usvseg detection 11203
# ava detection 11221 not matching with usvseg detection 11221
# ava detection 11223 not matching with usvseg detection 11223
# ava detection 11224 not matching with usvseg detection 11224
# ava detection 11278 not matching with usvseg detection 11278
# ava detection 11316 not matching with usvseg detection 11316
# ava detection 11323 not matching with usvseg detection 11323
# ava detection 11338 not matching with usvseg detection 11338
# ava detection 11344 not matching with usvseg detection 11344
# ava detection 11345 not matching with usvseg detection 11345
# ava detection 11403 not matching with usvseg detection 11403
# ava detection 11404 not matching with usvseg detection 11404
# ava detection 11407 not matching with usvseg detection 11407
# ava detection 11420 not matching with usvseg detection 11420
# ava detection 11452 not matching with usvseg detection 11452
# ava detection 11465 not matching with usvseg detection 11465
# ava detection 11479 not matching with usvseg detection 11479
# ava detection 11482 not matching with usvseg detection 11482
# ava detection 11483 not matching with usvseg detection 11483
# ava detection 11485 not matching with usvseg detection 11485
# ava detection 11487 not matching with usvseg detection 11487
# ava detection 11492 not matching with usvseg detection 11492
# ava detection 11510 not matching with usvseg detection 11510
# ava detection 11512 not matching with usvseg detection 11512
# ava detection 11540 not matching with usvseg detection 11540
# ava detection 11606 not matching with usvseg detection 11606
# ava detection 11615 not matching with usvseg detection 11615
# ava detection 11622 not matching with usvseg detection 11622
# ava detection 11624 not matching with usvseg detection 11624
# ava detection 11635 not matching with usvseg detection 11635
# ava detection 11636 not matching with usvseg detection 11636
# ava detection 11637 not matching with usvseg detection 11637
# ava detection 11638 not matching with usvseg detection 11638
# ava detection 11671 not matching with usvseg detection 11671
# ava detection 11680 not matching with usvseg detection 11680
# ava detection 11699 not matching with usvseg detection 11699
# ava detection 11703 not matching with usvseg detection 11703
# ava detection 11710 not matching with usvseg detection 11710
# ava detection 11726 not matching with usvseg detection 11726
# ava detection 11728 not matching with usvseg detection 11728
# ava detection 11730 not matching with usvseg detection 11730
# ava detection 11769 not matching with usvseg detection 11769
# ava detection 11781 not matching with usvseg detection 11781
# ava detection 11815 not matching with usvseg detection 11815
# ava detection 11818 not matching with usvseg detection 11818
# ava detection 11836 not matching with usvseg detection 11836
# ava detection 11877 not matching with usvseg detection 11877
# ava detection 11893 not matching with usvseg detection 11893
# ava detection 11962 not matching with usvseg detection 11962
# ava detection 11984 not matching with usvseg detection 11984
# ava detection 12008 not matching with usvseg detection 12008
# ava detection 12027 not matching with usvseg detection 12027
# ava detection 12033 not matching with usvseg detection 12033
# ava detection 12037 not matching with usvseg detection 12037
# ava detection 12040 not matching with usvseg detection 12040
# ava detection 12042 not matching with usvseg detection 12042
# ava detection 12043 not matching with usvseg detection 12043
# ava detection 12044 not matching with usvseg detection 12044
# ava detection 12047 not matching with usvseg detection 12047
# ava detection 12048 not matching with usvseg detection 12048
# ava detection 12051 not matching with usvseg detection 12051
# ava detection 12057 not matching with usvseg detection 12057
# ava detection 12063 not matching with usvseg detection 12063
# ava detection 12064 not matching with usvseg detection 12064
# ava detection 12065 not matching with usvseg detection 12065
# ava detection 12066 not matching with usvseg detection 12066
# ava detection 12067 not matching with usvseg detection 12067
# ava detection 12078 not matching with usvseg detection 12078
# ava detection 12086 not matching with usvseg detection 12086
# ava detection 12095 not matching with usvseg detection 12095
# ava detection 12124 not matching with usvseg detection 12124
# ava detection 12147 not matching with usvseg detection 12147
# ava detection 12151 not matching with usvseg detection 12151
# ava detection 12152 not matching with usvseg detection 12152
# ava detection 12166 not matching with usvseg detection 12166
# ava detection 12169 not matching with usvseg detection 12169
# ava detection 12175 not matching with usvseg detection 12175
# ava detection 12176 not matching with usvseg detection 12176
# ava detection 12177 not matching with usvseg detection 12177
# ava detection 12178 not matching with usvseg detection 12178
# ava detection 12179 not matching with usvseg detection 12179
# ava detection 12180 not matching with usvseg detection 12180
# ava detection 12184 not matching with usvseg detection 12184
# ava detection 12191 not matching with usvseg detection 12191
# ava detection 12193 not matching with usvseg detection 12193
# ava detection 12194 not matching with usvseg detection 12194
# ava detection 12198 not matching with usvseg detection 12198
# ava detection 12207 not matching with usvseg detection 12207
# ava detection 12215 not matching with usvseg detection 12215
# ava detection 12216 not matching with usvseg detection 12216
# ava detection 12217 not matching with usvseg detection 12217
# ava detection 12221 not matching with usvseg detection 12221
# ava detection 12223 not matching with usvseg detection 12223
# ava detection 12224 not matching with usvseg detection 12224
# ava detection 12225 not matching with usvseg detection 12225
# ava detection 12226 not matching with usvseg detection 12226
# ava detection 12246 not matching with usvseg detection 12246
# ava detection 12253 not matching with usvseg detection 12253
# ava detection 12286 not matching with usvseg detection 12286
# ava detection 12303 not matching with usvseg detection 12303
# ava detection 12312 not matching with usvseg detection 12312
# ava detection 12343 not matching with usvseg detection 12343
# ava detection 12344 not matching with usvseg detection 12344
# ava detection 12347 not matching with usvseg detection 12347
# ava detection 12348 not matching with usvseg detection 12348
# ava detection 12349 not matching with usvseg detection 12349
# ava detection 12350 not matching with usvseg detection 12350
# ava detection 12351 not matching with usvseg detection 12351
# ava detection 12352 not matching with usvseg detection 12352
# ava detection 12353 not matching with usvseg detection 12353
# ava detection 12354 not matching with usvseg detection 12354
# ava detection 12355 not matching with usvseg detection 12355
# ava detection 12356 not matching with usvseg detection 12356
# ava detection 12357 not matching with usvseg detection 12357
# ...
# ava detection 17862 not matching with usvseg detection 17862
# ava detection 17870 not matching with usvseg detection 17870
# ava detection 17876 not matching with usvseg detection 17876
# ava detection 17930 not matching with usvseg detection 17930
# ava detection 17962 not matching with usvseg detection 17962
# ava detection 17966 not matching with usvseg detection 17966
# ava detection 17982 not matching with usvseg detection 17982
# ava detection 17985 not matching with usvseg detection 17985
# ava detection 17997 not matching with usvseg detection 17997
# ava detection 18009 not matching with usvseg detection 18009
# ava detection 18026 not matching with usvseg detection 18026
# ava detection 18043 not matching with usvseg detection 18043
# ava detection 18070 not matching with usvseg detection 18070
# ava detection 18077 not matching with usvseg detection 18077
# ava detection 18093 not matching with usvseg detection 18093
# ava detection 18117 not matching with usvseg detection 18117
# ava detection 18154 not matching with usvseg detection 18154
# ava detection 18190 not matching with usvseg detection 18190
# ava detection 18193 not matching with usvseg detection 18193
# ava detection 18218 not matching with usvseg detection 18218
# ava detection 18219 not matching with usvseg detection 18219
# ava detection 18242 not matching with usvseg detection 18242
# ava detection 18243 not matching with usvseg detection 18243
# ava detection 18275 not matching with usvseg detection 18275
# ava detection 18278 not matching with usvseg detection 18278
# ava detection 18291 not matching with usvseg detection 18291
# ava detection 18292 not matching with usvseg detection 18292
# ava detection 18312 not matching with usvseg detection 18312
# ava detection 18315 not matching with usvseg detection 18315
# ava detection 18320 not matching with usvseg detection 18320
# ava detection 18331 not matching with usvseg detection 18331
# ava detection 18333 not matching with usvseg detection 18333
# ava detection 18334 not matching with usvseg detection 18334
# ava detection 18335 not matching with usvseg detection 18335
# ava detection 18416 not matching with usvseg detection 18416
# ava detection 18417 not matching with usvseg detection 18417
# ava detection 18419 not matching with usvseg detection 18419
# ava detection 18437 not matching with usvseg detection 18437
# ava detection 18570 not matching with usvseg detection 18570
# ava detection 18571 not matching with usvseg detection 18571
# ava detection 18608 not matching with usvseg detection 18608
# ava detection 18638 not matching with usvseg detection 18638
# ava detection 18700 not matching with usvseg detection 18700
# ava detection 18720 not matching with usvseg detection 18720
# ava detection 18755 not matching with usvseg detection 18755
# ava detection 18761 not matching with usvseg detection 18761
# ava detection 18808 not matching with usvseg detection 18808
# ava detection 18844 not matching with usvseg detection 18844
# ava detection 18856 not matching with usvseg detection 18856
# ava detection 18870 not matching with usvseg detection 18870
# ava detection 18880 not matching with usvseg detection 18880
# ava detection 18888 not matching with usvseg detection 18888
# ava detection 18891 not matching with usvseg detection 18891
# ava detection 18903 not matching with usvseg detection 18903
# ava detection 18905 not matching with usvseg detection 18905
# ava detection 18944 not matching with usvseg detection 18944
# ava detection 18950 not matching with usvseg detection 18950
# ava detection 18955 not matching with usvseg detection 18955
# ava detection 18973 not matching with usvseg detection 18973
# ava detection 18995 not matching with usvseg detection 18995
# ava detection 19020 not matching with usvseg detection 19020
# ava detection 19025 not matching with usvseg detection 19025
# ava detection 19026 not matching with usvseg detection 19026
# ava detection 19043 not matching with usvseg detection 19043
# ava detection 19065 not matching with usvseg detection 19065
# ava detection 19134 not matching with usvseg detection 19134
# ava detection 19141 not matching with usvseg detection 19141
# ava detection 19144 not matching with usvseg detection 19144
# ava detection 19163 not matching with usvseg detection 19163
# ava detection 19174 not matching with usvseg detection 19174
# ava detection 19175 not matching with usvseg detection 19175
# ava detection 19176 not matching with usvseg detection 19176
# ava detection 19200 not matching with usvseg detection 19200
# ava detection 19216 not matching with usvseg detection 19216
# ava detection 19221 not matching with usvseg detection 19221
# ava detection 19224 not matching with usvseg detection 19224
# ava detection 19225 not matching with usvseg detection 19225
# ava detection 19226 not matching with usvseg detection 19226
# ava detection 19227 not matching with usvseg detection 19227
# ava detection 19228 not matching with usvseg detection 19228
# ava detection 19229 not matching with usvseg detection 19229
# ava detection 19230 not matching with usvseg detection 19230
# ava detection 19231 not matching with usvseg detection 19231
# ava detection 19232 not matching with usvseg detection 19232
# ava detection 19233 not matching with usvseg detection 19233
# ava detection 19234 not matching with usvseg detection 19234
# ava detection 19235 not matching with usvseg detection 19235
# ava detection 19238 not matching with usvseg detection 19238
# ava detection 19239 not matching with usvseg detection 19239
# ava detection 19240 not matching with usvseg detection 19240
# ava detection 19241 not matching with usvseg detection 19241
# ava detection 19242 not matching with usvseg detection 19242
# ava detection 19243 not matching with usvseg detection 19243
# ava detection 19244 not matching with usvseg detection 19244
# ava detection 19245 not matching with usvseg detection 19245
# ava detection 19246 not matching with usvseg detection 19246
# ava detection 19247 not matching with usvseg detection 19247
# ava detection 19248 not matching with usvseg detection 19248
# ava detection 19249 not matching with usvseg detection 19249
# ava detection 19250 not matching with usvseg detection 19250
# ava detection 19251 not matching with usvseg detection 19251
# ava detection 19252 not matching with usvseg detection 19252
# ava detection 19253 not matching with usvseg detection 19253
# ava detection 19254 not matching with usvseg detection 19254
# ava detection 19255 not matching with usvseg detection 19255
# ava detection 19256 not matching with usvseg detection 19256
# ava detection 19257 not matching with usvseg detection 19257
# ava detection 19258 not matching with usvseg detection 19258
# ava detection 19262 not matching with usvseg detection 19262
# ava detection 19263 not matching with usvseg detection 19263
# ava detection 19264 not matching with usvseg detection 19264
# ava detection 19282 not matching with usvseg detection 19282
# ava detection 19323 not matching with usvseg detection 19323
# ava detection 19332 not matching with usvseg detection 19332
# ava detection 19353 not matching with usvseg detection 19353
# ava detection 19364 not matching with usvseg detection 19364
# ava detection 19365 not matching with usvseg detection 19365
# ava detection 19415 not matching with usvseg detection 19415
# ava detection 19421 not matching with usvseg detection 19421
# ava detection 19430 not matching with usvseg detection 19430
# ava detection 19436 not matching with usvseg detection 19436
# ava detection 19437 not matching with usvseg detection 19437
# ava detection 19441 not matching with usvseg detection 19441
# ava detection 19443 not matching with usvseg detection 19443
# ava detection 19449 not matching with usvseg detection 19449
# ava detection 19450 not matching with usvseg detection 19450
# ava detection 19456 not matching with usvseg detection 19456
# ava detection 19462 not matching with usvseg detection 19462
# ava detection 19463 not matching with usvseg detection 19463
# ava detection 19464 not matching with usvseg detection 19464
# ava detection 19469 not matching with usvseg detection 19469
# ava detection 19475 not matching with usvseg detection 19475
# ava detection 19501 not matching with usvseg detection 19501
# ava detection 19526 not matching with usvseg detection 19526
# ava detection 19528 not matching with usvseg detection 19528
# ava detection 19560 not matching with usvseg detection 19560
# ava detection 19564 not matching with usvseg detection 19564
# ava detection 19586 not matching with usvseg detection 19586
# ava detection 19593 not matching with usvseg detection 19593
# ava detection 19594 not matching with usvseg detection 19594
# ava detection 19595 not matching with usvseg detection 19595
# ava detection 19596 not matching with usvseg detection 19596
# ava detection 19632 not matching with usvseg detection 19632
# ava detection 19646 not matching with usvseg detection 19646
# ava detection 19653 not matching with usvseg detection 19653
# ava detection 19663 not matching with usvseg detection 19663
# ava detection 19675 not matching with usvseg detection 19675
# ava detection 19677 not matching with usvseg detection 19677
# ava detection 19686 not matching with usvseg detection 19686
# ava detection 19711 not matching with usvseg detection 19711
# ava detection 19712 not matching with usvseg detection 19712
# ava detection 19713 not matching with usvseg detection 19713
# ava detection 19714 not matching with usvseg detection 19714
# ava detection 19730 not matching with usvseg detection 19730
# ava detection 19739 not matching with usvseg detection 19739
# ava detection 19744 not matching with usvseg detection 19744
# ava detection 19746 not matching with usvseg detection 19746
# ava detection 19754 not matching with usvseg detection 19754
# ava detection 19755 not matching with usvseg detection 19755
# ava detection 19756 not matching with usvseg detection 19756
# ava detection 19757 not matching with usvseg detection 19757
# ava detection 19758 not matching with usvseg detection 19758
# ava detection 19780 not matching with usvseg detection 19780
# ava detection 19801 not matching with usvseg detection 19801
# ava detection 19826 not matching with usvseg detection 19826
# ava detection 19832 not matching with usvseg detection 19832
# ava detection 19833 not matching with usvseg detection 19833
# ava detection 19839 not matching with usvseg detection 19839
# ava detection 19844 not matching with usvseg detection 19844
# ava detection 19848 not matching with usvseg detection 19848
# ava detection 19853 not matching with usvseg detection 19853
# ava detection 19854 not matching with usvseg detection 19854
# ava detection 19855 not matching with usvseg detection 19855
# ava detection 19858 not matching with usvseg detection 19858
# ava detection 19859 not matching with usvseg detection 19859
# ava detection 19860 not matching with usvseg detection 19860
# ava detection 19861 not matching with usvseg detection 19861
# ava detection 19862 not matching with usvseg detection 19862
# ava detection 19895 not matching with usvseg detection 19895
# ava detection 19900 not matching with usvseg detection 19900
# ava detection 19917 not matching with usvseg detection 19917
# ava detection 19918 not matching with usvseg detection 19918
# ava detection 19919 not matching with usvseg detection 19919
# ava detection 19924 not matching with usvseg detection 19924
# ava detection 19937 not matching with usvseg detection 19937
# ava detection 19938 not matching with usvseg detection 19938
# ava detection 19939 not matching with usvseg detection 19939
# ava detection 19940 not matching with usvseg detection 19940
# ava detection 19941 not matching with usvseg detection 19941
# ava detection 19942 not matching with usvseg detection 19942
# ava detection 19943 not matching with usvseg detection 19943
# ava detection 19944 not matching with usvseg detection 19944
# ava detection 19945 not matching with usvseg detection 19945
# ava detection 19946 not matching with usvseg detection 19946
# ava detection 19947 not matching with usvseg detection 19947
# ava detection 19953 not matching with usvseg detection 19953
# ava detection 19957 not matching with usvseg detection 19957
# ava detection 19960 not matching with usvseg detection 19960
# ava detection 20015 not matching with usvseg detection 20015
# ava detection 20035 not matching with usvseg detection 20035
# ava detection 20036 not matching with usvseg detection 20036
# ava detection 20060 not matching with usvseg detection 20060
# ava detection 20089 not matching with usvseg detection 20089
# ava detection 20105 not matching with usvseg detection 20105
# ava detection 20124 not matching with usvseg detection 20124
# ava detection 20185 not matching with usvseg detection 20185
# ava detection 20209 not matching with usvseg detection 20209
# ava detection 20215 not matching with usvseg detection 20215
# ava detection 20218 not matching with usvseg detection 20218
# ava detection 20222 not matching with usvseg detection 20222
# ava detection 20224 not matching with usvseg detection 20224
# ava detection 20235 not matching with usvseg detection 20235
# ava detection 20244 not matching with usvseg detection 20244
# ava detection 20248 not matching with usvseg detection 20248
# ava detection 20268 not matching with usvseg detection 20268
# ava detection 20274 not matching with usvseg detection 20274
# ava detection 20307 not matching with usvseg detection 20307
# ava detection 20345 not matching with usvseg detection 20345
# ava detection 20353 not matching with usvseg detection 20353
# ava detection 20388 not matching with usvseg detection 20388
# ava detection 20462 not matching with usvseg detection 20462
# ava detection 20469 not matching with usvseg detection 20469
# ava detection 20478 not matching with usvseg detection 20478
# ava detection 20479 not matching with usvseg detection 20479
# ava detection 20507 not matching with usvseg detection 20507
# ava detection 20518 not matching with usvseg detection 20518
# ava detection 20536 not matching with usvseg detection 20536
# ava detection 20581 not matching with usvseg detection 20581
# ava detection 20582 not matching with usvseg detection 20582
# ava detection 20612 not matching with usvseg detection 20612
# ava detection 20688 not matching with usvseg detection 20688
# ava detection 20691 not matching with usvseg detection 20691
# ava detection 20694 not matching with usvseg detection 20694
# ava detection 20703 not matching with usvseg detection 20703
# ava detection 20716 not matching with usvseg detection 20716
# ava detection 20717 not matching with usvseg detection 20717
# ava detection 20718 not matching with usvseg detection 20718
# ava detection 20727 not matching with usvseg detection 20727
# ava detection 20743 not matching with usvseg detection 20743
# ava detection 20750 not matching with usvseg detection 20750
# ava detection 20751 not matching with usvseg detection 20751
# ava detection 20752 not matching with usvseg detection 20752
# ava detection 20753 not matching with usvseg detection 20753
# ava detection 20755 not matching with usvseg detection 20755
# ava detection 20757 not matching with usvseg detection 20757
# ava detection 20758 not matching with usvseg detection 20758
# ava detection 20759 not matching with usvseg detection 20759
# ava detection 20760 not matching with usvseg detection 20760
# ava detection 20794 not matching with usvseg detection 20794
# ava detection 20816 not matching with usvseg detection 20816
# ava detection 20818 not matching with usvseg detection 20818
# ava detection 20833 not matching with usvseg detection 20833
# ava detection 20838 not matching with usvseg detection 20838
# ava detection 20852 not matching with usvseg detection 20852
# ava detection 20854 not matching with usvseg detection 20854
# ava detection 20866 not matching with usvseg detection 20866
# ava detection 20871 not matching with usvseg detection 20871
# ava detection 20880 not matching with usvseg detection 20880
# ava detection 20895 not matching with usvseg detection 20895
# ava detection 20897 not matching with usvseg detection 20897
# ava detection 20901 not matching with usvseg detection 20901
# ava detection 20906 not matching with usvseg detection 20906

# %%
ava_embedding_detections.shape
# Out:
# (21837, 2)

# %% [markdown]
# ## Embed latent means

# %%
latent_means = dc.request('latent_means')
# Out:
# Reading field: latent_means
# 	Done with: latent_means

# %%
# Reorder latents so that they are in temporal sequence
latent_means = latent_means[ava_embedding_detections.index,:]

# %% [markdown]
# ## Cliff's manual labels

# %%
ava_embedding_detections['label'] = usvseg_detections['manual_type'].iloc[:ava_embedding_detections.shape[0]].copy()
ava_embedding_detections = pd.concat([ava_embedding_detections, pd.DataFrame(latent_means)],axis=1)

# %%
ava_embedding_detections.dropna(subset='label',inplace=True)
# Mapping from IDs to tokens, grouping multiple IDs to one token
tokenizer = {1:1,2:2,3:2,4:2,5:2,6:3,7:3,8:4,9:5,10:6,11:7,12:0}
ava_embedding_detections['label'] = [tokenizer[mtype] for mtype in ava_embedding_detections.label]

# %%
ava_embedding_detections = ava_embedding_detections[ava_embedding_detections.label != 0]
ava_embedding_detections

# %% [markdown]
# ## Append latents

# %%
detections_locations_all.reset_index(drop=True, inplace=True)
latents = pd.DataFrame(latent_means)
locations_latents_all = pd.concat([detections_locations_all, latents],axis=1)
locations_latents_all
# Out:
#        Unnamed: 0        start          end   duration  maxfreq  maxamp  \
# 0             0.0     0.499500     0.573000  43.500000   33.518  -74.43
# 1             1.0     0.599500     0.680400  51.000000   35.249  -73.59
# 2             2.0     0.664900     0.741900  47.000000   24.462  -65.25
# 3             3.0     0.699400     0.781400  52.000000   26.710  -67.75
# 4             4.0     0.801900     0.870900  39.000000   26.129  -58.83
# ...           ...          ...          ...        ...      ...     ...
# 21832         NaN  3784.295589  3784.354581   0.058993      NaN     NaN
# 21833         NaN  3784.454569  3784.498564   0.043995      NaN     NaN
# 21834      6044.0  3791.947400  3792.024900  47.500000   20.134  -58.69
# 21835      6045.0  3792.486400  3792.543800  27.500000   20.356  -68.72
# 21836      6046.0  3792.714300  3792.771800  27.500000   24.009  -71.25
#
#        meanfreq  cvfreq in_song  usvseg_index  ...        22        23  \
# 0        33.371  0.0732   False           0.0  ... -0.321951 -0.004976
# 1        38.586  0.2041   False           1.0  ...  0.716621 -0.006194
# 2        27.155  0.1779   False           0.0  ... -0.149974 -0.040295
# 3        36.812  0.3191   False           2.0  ...  1.128774 -0.019966
# 4        31.683  0.2641   False           3.0  ... -0.687927 -0.004163
# ...         ...     ...     ...           ...  ...       ...       ...
# 21832       NaN     NaN     NaN           NaN  ... -0.110711 -0.127445
# 21833       NaN     NaN     NaN           NaN  ... -0.215791 -0.097987
# 21834    20.996  0.0575   False        4666.0  ... -0.847291 -0.075674
# 21835    22.576  0.0815   False        4667.0  ... -0.500720 -0.052311
# 21836    21.751  0.0658   False        4668.0  ... -0.399492 -0.038788
#
#              24        25        26        27        28        29        30  \
# 0     -0.009897  1.071670 -0.048639  0.014466 -0.004134 -0.351411  0.035195
# 1     -0.003253  1.243603 -0.055185 -0.005874  0.004700 -0.595085  0.042283
# 2      0.002160  1.758230 -0.038398 -0.068613 -0.005556 -0.312204  0.076351
# 3      0.004840  1.402047 -0.060514 -0.014199  0.022991 -0.611689  0.057459
# 4      0.010576  1.201925 -0.041650 -0.019108 -0.000796 -0.507738  0.073795
# ...         ...       ...       ...       ...       ...       ...       ...
# 21832 -0.078923 -0.920009 -0.028742 -0.014675  0.007098  1.521373  0.120173
# 21833 -0.106544 -1.091271 -0.055277  0.013731  0.021517  1.565341  0.124663
# 21834 -0.061599 -0.845709 -0.039407 -0.055683  0.004596  0.194059  0.024943
# 21835 -0.025521 -0.018938 -0.024468 -0.055605 -0.043400  0.067176  0.037409
# 21836 -0.015981 -0.396217 -0.021078 -0.035979 -0.024221 -0.133873  0.030410
#
#              31
# 0     -0.008947
# 1      0.004533
# 2      0.004217
# 3      0.004964
# 4      0.005437
# ...         ...
# 21832 -0.008331
# 21833 -0.019403
# 21834  0.019616
# 21835 -0.005561
# 21836  0.013622
#
# [21837 rows x 74 columns]

# %% [markdown]
# ## Save

# %%
locations_latents_all.to_csv(seg_dirs[0]+'/locations_latents_all.csv', index=False)
