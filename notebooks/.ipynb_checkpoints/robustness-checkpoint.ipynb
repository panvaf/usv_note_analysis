# %% [markdown]
# # Access similarity of representations of different runs of AVA in sample dataset

# %% [markdown]
# ## Import modules

# %%
import h5py
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import umap
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
from ava.data.data_container import DataContainer
import audio_utils.io

# %%
# %matplotlib inline

# %% [markdown]
# ## Samples and networks paths

# %%
root = '/mnt/labNAS/usv_calls/usv_note_analysis'
models = ['230118_MZ18_MZ23_1_run1_long','230118_MZ18_MZ23_1_run2']
projection_dirs = [os.path.join(root, model, 'projections_sampl') for model in models]
spec_dirs = [os.path.join(root, models[0], 'specs_sampl')]
model_filenames = [os.path.join(root, model, 'checkpoint_010.tar') for model in models]
dcs = [DataContainer(projection_dirs=projection_dir, spec_dirs=spec_dirs, model_filename=model_filenames)
       for projection_dir, model_filename in zip(projection_dirs, model_filenames)]

# %%
model_filenames
# Out:
# ['/mnt/labNAS/usv_calls/usv_note_analysis/230118_MZ18_MZ23_1_run1_long/checkpoint_010.tar',
#  '/mnt/labNAS/usv_calls/usv_note_analysis/230118_MZ18_MZ23_1_run2/checkpoint_010.tar']

# %%
onsets = dcs[0].request('onsets')
offsets = dcs[0].request('offsets')
ava_embedding_detections1 = pd.DataFrame(np.vstack([onsets, offsets]).T, columns=['onsets', 'offsets'])
#ava_embedding_detections = ava_embedding_detections.sort_values('onsets',ascending=True)
ava_embedding_detections1
# Out:
# Reading field: onsets

# %% [markdown]
# ## Embed latent means

# %%
latent_means1 = dc.request('latent_means')
# Out:
# Making field: latent_means
# Making field: latent_means
# 	Done with: latent_means

# %%
latent_means = dc.request('latent_means')
# Out:
# Reading field: latent_means
# 	Done with: latent_means

# %% [markdown]
# ## Representation similarity analysis

# %%
#distance_matrix = euclidean_distances(latent_means)
#similarity_matrix = 1/(1+distance_matrix)
similarity_matrix = cosine_similarity(latent_means)
linkage_matrix = linkage(similarity_matrix, method='complete')

# %%
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix)
plt.xlabel('Vectors')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %%
# Get the order of samples in the clustered tree
leaves_list = dendrogram(linkage_matrix, no_plot=True)['leaves']

# Reorder the similarity matrix based on the clustering
reordered_matrix = similarity_matrix[leaves_list][:, leaves_list]

plt.imshow(reordered_matrix)

# %%
#distance_matrix1 = euclidean_distances(latent_means1)
#similarity_matrix1 = 1/(1+distance_matrix1)
similarity_matrix1 = cosine_similarity(latent_means1)
reordered_matrix1 = similarity_matrix1[leaves_list][:, leaves_list]

plt.imshow(reordered_matrix1)
