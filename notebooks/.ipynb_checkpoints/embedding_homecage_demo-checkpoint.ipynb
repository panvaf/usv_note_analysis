# %% [markdown]
# # For homecage usv, try embedding spectrograms and embedding latent means

# %% [markdown]
# ## import modules

# %%
import h5py
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import umap
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
from ava.data.data_container import DataContainer
import audio_utils.io

# %%
# %matplotlib inline

# %% [markdown]
# ## ava project path

# %%
root = '/mnt/labNAS/usv_calls/usv_note_analysis/230319_dyad_05'
audio_dirs = [os.path.join(root, 'audio')]
seg_dirs = [os.path.join(root, 'segs')]
proj_dirs = [os.path.join(root, 'projections')]
spec_dirs = [os.path.join(root, 'specs')]
model_filename = os.path.join(root, 'checkpoint_750.tar')
plots_dir = root
dc = DataContainer(projection_dirs=proj_dirs, spec_dirs=spec_dirs, plots_dir=plots_dir, model_filename=model_filename)

# %%
onsets = dc.request('onsets')
offsets = dc.request('offsets')
ava_embedding_detections = pd.DataFrame(np.vstack([onsets, offsets]).T, columns=['onsets', 'offsets'])
ava_embedding_detections
# Out:
# Reading field: onsets
# 	Done with: onsets
# Reading field: offsets
# 	Done with: offsets
#           onsets    offsets
# 0         0.2230     0.3370
# 1         0.8754     0.9919
# 2         2.8573     2.9063
# 3         2.9222     2.9787
# 4         3.4012     3.4557
# ...          ...        ...
# 15394  3689.1102  3689.2347
# 15395  3690.4091  3690.4926
# 15396  3691.4775  3691.5650
# 15397  3691.7680  3691.8420
# 15398  3691.8690  3691.9140
#
# [15399 rows x 2 columns]

# %% [markdown]
# ## embed latent means

# %%
latent_means = dc.request('latent_means')
# Out:
# Reading field: latent_means
# 	Done with: latent_means

# %%
# try umap
transform = umap.UMAP(n_components=2, n_neighbors=20, min_dist=0.01, metric='euclidean', random_state=42)
embedding = transform.fit_transform(latent_means)

# %%
fig, ax = plt.subplots(figsize=(6,5))
sc = ax.scatter(embedding[:,0], embedding[:,1], s=1)
plt.tight_layout()
plt.show()

# %%
# from ava.plotting.tooltip_plot import tooltip_plot_DC
# from ava.plotting.latent_projection import latent_projection_plot_DC
# latent_projection_plot_DC(dc)
# tooltip_plot_DC(dc, num_imgs=2000)

# %% [markdown]
# ## get features

# %%
usvseg_filepaths = glob.glob(os.path.join(root, 'usvseg', '*.csv'))
usvseg_detections = pd.concat([audio_utils.io.read_usv_detections(f) for f in usvseg_filepaths], ignore_index=True)
usvseg_detections
# Out:
#            start        end  duration  maxfreq  maxamp  meanfreq  cvfreq  \
# 0         0.2380     0.3220      84.0   64.629  -44.64    49.170  0.2567
# 1         0.8904     0.9769      86.5   66.187  -58.26    47.962  0.3195
# 2         2.8723     2.8913      19.0   60.041  -61.11    48.741  0.2829
# 3         2.9372     2.9637      26.5   29.142  -61.44    30.565  0.0633
# 4         3.4162     3.4407      24.5   60.843  -59.66    52.896  0.4293
# ...          ...        ...       ...      ...     ...       ...     ...
# 15394  3689.1252  3689.2197      94.5   26.019  -45.75    30.575  0.5203
# 15395  3690.4241  3690.4776      53.5   23.733  -53.43    26.579  0.2008
# 15396  3691.4925  3691.5500      57.5   24.794  -48.22    28.835  0.3518
# 15397  3691.7830  3691.8270      44.0   98.855  -66.88    68.636  0.3828
# 15398  3691.8840  3691.8990      15.0   15.454  -42.28    15.746  0.0137
#
#        in_song
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 15394    False
# 15395    False
# 15396    False
# 15397    False
# 15398    False
#
# [15399 rows x 8 columns]

# %%
for i in range(ava_embedding_detections.shape[0]):
    ava_onset = ava_embedding_detections.iloc[i,0]
    usvseg_onset = usvseg_detections.iloc[i,0]
    if abs(ava_onset+0.015-usvseg_onset)>1e-3:
        print(f'ava detection {i} not matching with usvseg detection {i}')

# %%
fig, ax = plt.subplots(figsize=(6,5))
sc = ax.scatter(embedding[:,0], embedding[:,1], s=1, c=usvseg_detections['duration'])
cbar = plt.colorbar(sc)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## embed spectrograms

# %%
specs = dc.request('specs')
# Out:
# Reading field: specs
# 	Done with: specs

# %%
specs_linearized = specs.reshape(specs.shape[0], -1)
scaler = StandardScaler()
specs_linearized_zscore = scaler.fit_transform(specs_linearized.T).T
specs_linearized_zscore.shape
# Out:
# (15399, 16384)

# %%
print(np.mean(specs_linearized_zscore, axis=1).shape)
print(np.mean(specs_linearized_zscore, axis=1))
# Out:
# (15399,)
# [-3.46944695e-17  3.46944695e-17 -2.42861287e-17 ...  4.16333634e-17
#  -1.38777878e-17 -1.38777878e-17]

# %%
# try umap
transform = umap.UMAP(n_components=2, n_neighbors=100, min_dist=0.01, metric='euclidean', random_state=42)
embedding = transform.fit_transform(specs_linearized_zscore)

# %%
fig, ax = plt.subplots(figsize=(6,5))
sc = ax.scatter(embedding[:,0], embedding[:,1], s=1, c=usvseg_detections['duration'])
cbar = plt.colorbar(sc)
plt.tight_layout()
plt.show()
